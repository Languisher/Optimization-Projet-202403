# %%
import numpy as np
import matplotlib.pyplot as plt

import scienceplots
plt.style.use(['nature', 'ieee'])

# %%
from vehicle import Vehicle
from route import Route
from simulation import Simulation

# %%
min_time = np.inf
for _ in range(1000000):
    vehi = Vehicle(mass=18000,
               frontal_area=8.16,
               velocity_init=5,
               energy_left=15000,
               velocity_max=60,
               energy_max=15000)

    # Define the Route. Ensure the parameters for each segment are correct (distance, incline angle, and friction coefficient)
    rout = Route(((10, 0, 0.015),)  # Each tuple represents a segment: (distance in meters, incline angle in degrees, friction coefficient)
                , delta_s=0.5)
    sim = Simulation(vehi, rout, distance_step=0.5)  # Optionally, you can specify other parameters like drag_coefficient or efficiency
    sim.simulate()
    
    if sim.time_list[-1] < min_time:
        if np.abs(sim.distance_list[-1]-sim.route.distance_list[-1])< 0.5:
            min_time=sim.time_list[-1]
            final_sim = sim 
print(min_time)
print(sim.time_list[-1])
final_sim.plot_results()
# Out:
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# ...

# %%
min_time = np.inf

for _ in range(1000000):
    vehi = Vehicle(mass=18000,
               frontal_area=8.16,
               velocity_init=5,
               energy_left=15000,
               velocity_max=60,
               energy_max=15000)

    # Define the Route. Ensure the parameters for each segment are correct (distance, incline angle, and friction coefficient)
    rout = Route(((10, 0, 0.015),)  # Each tuple represents a segment: (distance in meters, incline angle in degrees, friction coefficient)
                , delta_s=0.25)
    sim = Simulation(vehi, rout, distance_step=0.25)  # Optionally, you can specify other parameters like drag_coefficient or efficiency
    sim.simulate()
    
    if sim.time_list[-1] < min_time:
        if np.abs(sim.distance_list[-1]-sim.route.distance_list[-1])< 0.25:
            sum+=1
            min_time=sim.time_list[-1]
            final_sim = sim 

print(min_time)
print(sim.time_list[-1])
final_sim.plot_results()
# Out:
# 7
# 1626.1832706015052
# 3877.483979378731
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# ...

# %%
min_time = np.inf
for _ in range(100000):
    vehi = Vehicle(mass=18000,
               frontal_area=8.16,
               velocity_init=5,
               energy_left=15000,
               velocity_max=60,
               energy_max=15000)

    # Define the Route. Ensure the parameters for each segment are correct (distance, incline angle, and friction coefficient)
    rout = Route(((10, 5, 0.015),)  # Each tuple represents a segment: (distance in meters, incline angle in degrees, friction coefficient)
                , delta_s=0.5)
    sim = Simulation(vehi, rout, distance_step=0.5)  # Optionally, you can specify other parameters like drag_coefficient or efficiency
    sim.simulate()
    
    if sim.time_list[-1] < min_time:
        if np.abs(sim.distance_list[-1]-sim.route.distance_list[-1])< 0.5:
            min_time= sim.time_list[-1]
            final_sim = sim 
print(min_time)  
print(sim.time_list[-1])
final_sim.plot_results()
# Out:
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# ...

# %%
min_time = np.inf
for _ in range(1000000):
    vehi = Vehicle(mass=18000,
               frontal_area=8.16,
               velocity_init=5,
               energy_left=15000,
               velocity_max=60,
               energy_max=15000)

    # Define the Route. Ensure the parameters for each segment are correct (distance, incline angle, and friction coefficient)
    rout = Route(((10, 10, 0.015),)  # Each tuple represents a segment: (distance in meters, incline angle in degrees, friction coefficient)
                , delta_s=0.5)
    sim = Simulation(vehi, rout, distance_step=0.5)  # Optionally, you can specify other parameters like drag_coefficient or efficiency
    sim.simulate()
    
    if sim.time < min_time:
        if np.abs(sim.distance_list[-1]-sim.route.distance_list[-1])< 0.5:
            final_sim = sim 
print(min_time)  
print(sim.time_list[-1])
final_sim.plot_results()

# %%
min_time = np.inf

for _ in range(100000):
    vehi = Vehicle(mass=18000,
               frontal_area=8.16,
               velocity_init=5,
               energy_left=15000,
               velocity_max=60,
               energy_max=15000)

    # Define the Route. Ensure the parameters for each segment are correct (distance, incline angle, and friction coefficient)
    rout = Route(((4, 5, 0.015),(2, -5, 0.015),(4, 5, 0.015))  # Each tuple represents a segment: (distance in meters, incline angle in degrees, friction coefficient)
                , delta_s=0.5)
    sim = Simulation(vehi, rout, distance_step=0.5)  # Optionally, you can specify other parameters like drag_coefficient or efficiency
    sim.simulate()
    
    if sim.time_list[-1] < min_time:
        if np.abs(sim.distance_list[-1]-np.sum(sim.route.distance_list))< 0.5:

            min_time=sim.time_list[-1]
            final_sim = sim 

print(min_time)  
print(sim.time_list[-1])
final_sim.plot_results()
# Out:
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# ...
